# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
import bs4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Creating Empty Lists
pages=[]
prices=[]
ratings=[]
titles=[]
urls=[]

# %%
no_of_pages=2 ## Number of pages to be selected

## Looping through the required pages
for i in range(1,no_of_pages+1):
  url=("https://books.toscrape.com/catalogue/page-{}.html".format(i))
  pages.append(url) ## Adding the contents of specific pages

# %%
print("Number of pages", len(pages))
print(pages)
# Out:
# Number of pages 2
# ['https://books.toscrape.com/catalogue/page-1.html', 'https://books.toscrape.com/catalogue/page-2.html']

# %% [markdown]
# ## Getting the Data and converting it into readable format

# %%
for item in pages:
  page=requests.get(item)
  soup=bs4.BeautifulSoup(page.text,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# ## Titles

# %%
for t in soup.findAll('h3'):
  print(t)
# Out:
# <h3><a href="in-her-wake_980/index.html" title="In Her Wake">In Her Wake</a></h3>
# <h3><a href="how-music-works_979/index.html" title="How Music Works">How Music Works</a></h3>
# <h3><a href="foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html" title="Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More">Foolproof Preserving: A Guide ...</a></h3>
# <h3><a href="chase-me-paris-nights-2_977/index.html" title="Chase Me (Paris Nights #2)">Chase Me (Paris Nights ...</a></h3>
# <h3><a href="black-dust_976/index.html" title="Black Dust">Black Dust</a></h3>
# <h3><a href="birdsong-a-story-in-pictures_975/index.html" title="Birdsong: A Story in Pictures">Birdsong: A Story in ...</a></h3>
# ...

# %%
for t in soup.findAll('h3'):
  print(t.getText())
# Out:
# In Her Wake
# How Music Works
# Foolproof Preserving: A Guide ...
# Chase Me (Paris Nights ...
# Black Dust
# Birdsong: A Story in ...
# America's Cradle of Quarterbacks: ...
# Aladdin and His Wonderful ...
# Worlds Elsewhere: Journeys Around ...
# Wall and Piece
# The Four Agreements: A ...
# The Five Love Languages: ...
# The Elephant Tree
# The Bear and the ...
# Sophie's World
# Penny Maybe
# Maude (1883-1993):She Grew Up ...
# In a Dark, Dark ...
# Behind Closed Doors
# You can't bury them ...

# %%
for t in soup.findAll('h3'):
  titless=t.getText()
  titles.append(titless)

# %%
titles
# Out:
# ['In Her Wake',
#  'How Music Works',
#  'Foolproof Preserving: A Guide ...',
#  'Chase Me (Paris Nights ...',
#  'Black Dust',
#  'Birdsong: A Story in ...',
#  "America's Cradle of Quarterbacks: ...",
#  'Aladdin and His Wonderful ...',
#  'Worlds Elsewhere: Journeys Around ...',
#  'Wall and Piece',
#  'The Four Agreements: A ...',
#  'The Five Love Languages: ...',
#  'The Elephant Tree',
#  'The Bear and the ...',
#  "Sophie's World",
#  'Penny Maybe',
#  'Maude (1883-1993):She Grew Up ...',
#  'In a Dark, Dark ...',
#  'Behind Closed Doors',
#  "You can't bury them ..."]

# %% [markdown]
# ## Finding all the prices

# %%
for p in soup.find_all('p',class_='price_color'):
  price=p.getText()
  prices.append(price)

# %%
prices
# Out:
# ['Â£12.84',
#  'Â£37.32',
#  'Â£30.52',
#  'Â£25.27',
#  'Â£34.53',
#  'Â£54.64',
#  'Â£22.50',
#  'Â£53.13',
#  'Â£40.30',
#  'Â£44.18',
#  'Â£17.66',
#  'Â£31.05',
#  'Â£23.82',
#  'Â£36.89',
#  'Â£15.94',
#  'Â£33.29',
#  'Â£18.02',
#  'Â£19.63',
#  'Â£52.22',
#  'Â£33.63']

# %%
 soup.find_all('p',class_='star-rating')
# Out:
# [<p class="star-rating One">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>, <p class="star-rating Two">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>, <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>, <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>, <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>, <p class="star-rating Three">
#  <i class="icon-star"></i>
# ...

# %%
for s in soup.find_all('p',class_='star-rating'):
  for k,v in s.attrs.items():
    star=v[1]
    ratings.append(star)
    print(star)
# Out:
# One
# Two
# Three
# Five
# Five
# Three
# Three
# Three
# Five
# Four
# Five
# Three
# Five
# One
# Five
# Three
# Two
# One
# Four
# Two

# %%
k
# Out:
# 'class'

# %%
v
# Out:
# ['star-rating', 'Two']

# %% [markdown]
# ## URLs

# %%
soup.find_all('div',class_='image_container')
# Out:
# [<div class="image_container">
#  <a href="in-her-wake_980/index.html"><img alt="In Her Wake" class="thumbnail" src="../media/cache/5d/72/5d72709c6a7a9584a4d1cf07648bfce1.jpg"/></a>
#  </div>, <div class="image_container">
#  <a href="how-music-works_979/index.html"><img alt="How Music Works" class="thumbnail" src="../media/cache/5c/c8/5cc8e107246cb478960d4f0aba1e1c8e.jpg"/></a>
#  </div>, <div class="image_container">
#  <a href="foolproof-preserving-a-guide-to-small-batch-jams-jellies-pickles-condiments-and-more-a-foolproof-guide-to-making-small-batch-jams-jellies-pickles-condiments-and-more_978/index.html"><img alt="Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More" class="thumbnail" src="../media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg"/></a>
#  </div>, <div class="image_container">
# ...

# %%
divs=soup.find_all('div',class_='image_container')
for thumbs in divs:
  tagss=thumbs.find('img',class_='thumbnail')
  links='https://books.toscrape.com/'+str(tagss['src'])
  newlinks=links.replace('..','')
  urls.append(newlinks)

# %%
tagss
# Out:
# <img alt="You can't bury them all: Poems" class="thumbnail" src="../media/cache/e9/20/e9203b733126c4a0832a1c7885dc27cf.jpg"/>

# %%
tagss['src']
# Out:
# '../media/cache/e9/20/e9203b733126c4a0832a1c7885dc27cf.jpg'

# %%
links
# Out:
# 'https://books.toscrape.com/../media/cache/e9/20/e9203b733126c4a0832a1c7885dc27cf.jpg'

# %%
newlinks
# Out:
# 'https://books.toscrape.com//media/cache/e9/20/e9203b733126c4a0832a1c7885dc27cf.jpg'

# %%
urls
# Out:
# ['https://books.toscrape.com//media/cache/5d/72/5d72709c6a7a9584a4d1cf07648bfce1.jpg',
#  'https://books.toscrape.com//media/cache/5c/c8/5cc8e107246cb478960d4f0aba1e1c8e.jpg',
#  'https://books.toscrape.com//media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg',
#  'https://books.toscrape.com//media/cache/9c/2e/9c2e0eb8866b8e3f3b768994fd3d1c1a.jpg',
#  'https://books.toscrape.com//media/cache/44/cc/44ccc99c8f82c33d4f9d2afa4ef25787.jpg',
#  'https://books.toscrape.com//media/cache/af/6e/af6e796160fe63e0cf19d44395c7ddf2.jpg',
#  'https://books.toscrape.com//media/cache/ef/0b/ef0bed08de4e083dba5e20fdb98d9c36.jpg',
#  'https://books.toscrape.com//media/cache/d6/da/d6da0371958068bbaf39ea9c174275cd.jpg',
#  'https://books.toscrape.com//media/cache/2e/98/2e98c332bf8563b584784971541c4445.jpg',
#  'https://books.toscrape.com//media/cache/a5/41/a5416b9646aaa7287baa287ec2590270.jpg',
#  'https://books.toscrape.com//media/cache/0f/7e/0f7ee69495c0df1d35723f012624a9f8.jpg',
# ...

# %% [markdown]
# ## Data Pre-processing on scraped Data

# %%
data={'Title':titles,"Price":prices,"Rating":ratings,"URL":urls}

# %%
data
# Out:
# {'Title': ['In Her Wake',
#   'How Music Works',
#   'Foolproof Preserving: A Guide ...',
#   'Chase Me (Paris Nights ...',
#   'Black Dust',
#   'Birdsong: A Story in ...',
#   "America's Cradle of Quarterbacks: ...",
#   'Aladdin and His Wonderful ...',
#   'Worlds Elsewhere: Journeys Around ...',
#   'Wall and Piece',
#   'The Four Agreements: A ...',
#   'The Five Love Languages: ...',
#   'The Elephant Tree',
#   'The Bear and the ...',
#   "Sophie's World",
#   'Penny Maybe',
#   'Maude (1883-1993):She Grew Up ...',
#   'In a Dark, Dark ...',
#   'Behind Closed Doors',
#   "You can't bury them ..."],
#  'Price': ['Â£12.84',
#   'Â£37.32',
#   'Â£30.52',
#   'Â£25.27',
#   'Â£34.53',
#   'Â£54.64',
#   'Â£22.50',
#   'Â£53.13',
#   'Â£40.30',
#   'Â£44.18',
#   'Â£17.66',
#   'Â£31.05',
#   'Â£23.82',
#   'Â£36.89',
#   'Â£15.94',
#   'Â£33.29',
#   'Â£18.02',
#   'Â£19.63',
#   'Â£52.22',
#   'Â£33.63'],
#  'Rating': ['One',
#   'Two',
#   'Three',
#   'Five',
#   'Five',
# ...

# %%
print(len(titles))
print(len(prices))
print(len(ratings))
print(len(urls))
# Out:
# 20
# 20
# 20
# 20

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                     Title    Price Rating  \
# 0                             In Her Wake  Â£12.84    One
# 1                         How Music Works  Â£37.32    Two
# 2       Foolproof Preserving: A Guide ...  Â£30.52  Three
# 3              Chase Me (Paris Nights ...  Â£25.27   Five
# 4                              Black Dust  Â£34.53   Five
# 5                Birdsong: A Story in ...  Â£54.64  Three
# 6   America's Cradle of Quarterbacks: ...  Â£22.50  Three
# 7           Aladdin and His Wonderful ...  Â£53.13  Three
# 8   Worlds Elsewhere: Journeys Around ...  Â£40.30   Five
# 9                          Wall and Piece  Â£44.18   Four
# 10             The Four Agreements: A ...  Â£17.66   Five
# 11           The Five Love Languages: ...  Â£31.05  Three
# 12                      The Elephant Tree  Â£23.82   Five
# 13                   The Bear and the ...  Â£36.89    One
# 14                         Sophie's World  Â£15.94   Five
# ...

# %%
df['Price']=df['Price'].str.replace('Â£','')

# %%
df
# Out:
#                                     Title  Price Rating  \
# 0                             In Her Wake  12.84    One
# 1                         How Music Works  37.32    Two
# 2       Foolproof Preserving: A Guide ...  30.52  Three
# 3              Chase Me (Paris Nights ...  25.27   Five
# 4                              Black Dust  34.53   Five
# 5                Birdsong: A Story in ...  54.64  Three
# 6   America's Cradle of Quarterbacks: ...  22.50  Three
# 7           Aladdin and His Wonderful ...  53.13  Three
# 8   Worlds Elsewhere: Journeys Around ...  40.30   Five
# 9                          Wall and Piece  44.18   Four
# 10             The Four Agreements: A ...  17.66   Five
# 11           The Five Love Languages: ...  31.05  Three
# 12                      The Elephant Tree  23.82   Five
# 13                   The Bear and the ...  36.89    One
# 14                         Sophie's World  15.94   Five
# 15                            Penny Maybe  33.29  Three
# ...

# %% [markdown]
# ## Sorting the price from high to low

# %%
df.sort_values(by="Price",ascending=False)
# Out:
#                                     Title  Price Rating  \
# 5                Birdsong: A Story in ...  54.64  Three
# 7           Aladdin and His Wonderful ...  53.13  Three
# 18                    Behind Closed Doors  52.22   Four
# 9                          Wall and Piece  44.18   Four
# 8   Worlds Elsewhere: Journeys Around ...  40.30   Five
# 1                         How Music Works  37.32    Two
# 13                   The Bear and the ...  36.89    One
# 4                              Black Dust  34.53   Five
# 19                You can't bury them ...  33.63    Two
# 15                            Penny Maybe  33.29  Three
# 11           The Five Love Languages: ...  31.05  Three
# 2       Foolproof Preserving: A Guide ...  30.52  Three
# 3              Chase Me (Paris Nights ...  25.27   Five
# 12                      The Elephant Tree  23.82   Five
# 6   America's Cradle of Quarterbacks: ...  22.50  Three
# 17                    In a Dark, Dark ...  19.63    One
# ...

# %% [markdown]
# ## Convert Ratings columns into integers

# %%
df['Rating']=df['Rating'].replace({'One':1,"Two":2,"Three":3,"Four":4,"Five":5})

# %%
df
# Out:
#                                     Title  Price  Rating  \
# 0                             In Her Wake  12.84       1
# 1                         How Music Works  37.32       2
# 2       Foolproof Preserving: A Guide ...  30.52       3
# 3              Chase Me (Paris Nights ...  25.27       5
# 4                              Black Dust  34.53       5
# 5                Birdsong: A Story in ...  54.64       3
# 6   America's Cradle of Quarterbacks: ...  22.50       3
# 7           Aladdin and His Wonderful ...  53.13       3
# 8   Worlds Elsewhere: Journeys Around ...  40.30       5
# 9                          Wall and Piece  44.18       4
# 10             The Four Agreements: A ...  17.66       5
# 11           The Five Love Languages: ...  31.05       3
# 12                      The Elephant Tree  23.82       5
# 13                   The Bear and the ...  36.89       1
# 14                         Sophie's World  15.94       5
# ...

# %%
df.dtypes
# Out:
# Title     object
# Price     object
# Rating     int64
# URL       object
# dtype: object

# %% [markdown]
# ## Convert Price column from string to float

# %%
df['Price']=df["Price"].astype(float)

# %%
df.dtypes
# Out:
# Title      object
# Price     float64
# Rating      int64
# URL        object
# dtype: object

# %%
df.corr()
# Out:
#            Price    Rating
# Price   1.000000  0.070294
# Rating  0.070294  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
